# %% [markdown]
# # Chapter 2: Being Clear and Direct
#
# - [Lesson](#lesson)
# - [Exercises](#exercises)
# - [Example Playground](#example-playground)
#
# ## Setup
#
# Run the following setup cell to load your API key and establish the `get_completion` helper function.

# %%
# !pip install anthropic

# Import python's built-in regular expression library
import re
import anthropic

# Retrieve the API_KEY & MODEL_NAME variables from the IPython store
# %store -r API_KEY
# %store -r MODEL_NAME

client = anthropic.Anthropic(api_key=API_KEY)

# Note that we changed max_tokens to 4K just for this lesson to allow for longer completions in the exercises
def get_completion(prompt: str, system_prompt=""):
    message = client.messages.create(
        model=MODEL_NAME,
        max_tokens=4000,
        temperature=0.0,
        system=system_prompt,
        messages=[
          {"role": "user", "content": prompt}
        ]
    )
    return message.content[0].text
# Out:
# Requirement already satisfied: anthropic in /Users/teeritploensin/Document/prompt-eng-interactive-tutorial/venv/lib/python3.14/site-packages (0.116.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/teeritploensin/Document/prompt-eng-interactive-tutorial/venv/lib/python3.14/site-packages (from anthropic) (4.14.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/teeritploensin/Document/prompt-eng-interactive-tutorial/venv/lib/python3.14/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /Users/teeritploensin/Document/prompt-eng-interactive-tutorial/venv/lib/python3.14/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/teeritploensin/Document/prompt-eng-interactive-tutorial/venv/lib/python3.14/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/teeritploensin/Document/prompt-eng-interactive-tutorial/venv/lib/python3.14/site-packages (from anthropic) (0.16.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/teeritploensin/Document/prompt-eng-interactive-tutorial/venv/lib/python3.14/site-packages (from anthropic) (2.13.4)
# Requirement already satisfied: sniffio in /Users/teeritploensin/Document/prompt-eng-interactive-tutorial/venv/lib/python3.14/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /Users/teeritploensin/Document/prompt-eng-interactive-tutorial/venv/lib/python3.14/site-packages (from anthropic) (4.16.0)
# Requirement already satisfied: idna>=2.8 in /Users/teeritploensin/Document/prompt-eng-interactive-tutorial/venv/lib/python3.14/site-packages (from anyio<5,>=3.5.0->anthropic) (3.18)
# Requirement already satisfied: certifi in /Users/teeritploensin/Document/prompt-eng-interactive-tutorial/venv/lib/python3.14/site-packages (from httpx<1,>=0.25.0->anthropic) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /Users/teeritploensin/Document/prompt-eng-interactive-tutorial/venv/lib/python3.14/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/teeritploensin/Document/prompt-eng-interactive-tutorial/venv/lib/python3.14/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/teeritploensin/Document/prompt-eng-interactive-tutorial/venv/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/teeritploensin/Document/prompt-eng-interactive-tutorial/venv/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/teeritploensin/Document/prompt-eng-interactive-tutorial/venv/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)

# %% [markdown]
# ---
#
# ## Lesson
#
# **Claude responds best to clear and direct instructions.**
#
# Think of Claude like any other human that is new to the job. **Claude has no context** on what to do aside from what you literally tell it. Just as when you instruct a human for the first time on a task, the more you explain exactly what you want in a straightforward manner to Claude, the better and more accurate Claude's response will be."
#
# When in doubt, follow the **Golden Rule of Clear Prompting**:
# - Show your prompt to a colleague or friend and have them follow the instructions themselves to see if they can produce the result you want. If they're confused, Claude's confused.

# %% [markdown]
# ### Examples
#
# Let's take a task like writing poetry. (Ignore any syllable mismatch - LLMs aren't great at counting syllables yet.)

# %%
# Prompt
PROMPT = "Write a haiku about robots."

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# Metal minds awake,
# Dancing through electric dreams—
# Steel hearts beat as one.

# %% [markdown]
# This haiku is nice enough, but users may want Claude to go directly into the poem without the "Here is a haiku" preamble.
#
# How do we achieve that? We **ask for it**!

# %%
# Prompt
PROMPT = "Write a haiku about robots. Skip the preamble; go straight into the poem."

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# Metal minds awake
# Dancing through electric dreams
# Steel hearts beat as one

# %% [markdown]
# Here's another example. Let's ask Claude who's the best basketball player of all time. You can see below that while Claude lists a few names, **it doesn't respond with a definitive "best"**.

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time?"

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# That's one of sports' most debated questions, with no definitive answer. The most common candidates are:
#
# **Michael Jordan** - Often cited as #1 for his 6 championships, competitive drive, and dominance in the 1990s
#
# **LeBron James** - Longevity, all-around skills, and sustained excellence across multiple decades
#
# **Kareem Abdul-Jabbar** - All-time scoring leader for decades, incredible consistency
#
# **Magic Johnson & Larry Bird** - Revolutionized the game in the 1980s
#
# **Wilt Chamberlain & Bill Russell** - Dominated earlier eras
#
# The "best" depends on what you value: championships, individual stats, era-adjusted performance, peak vs. longevity, or all-around game. Most basketball analysts lean toward Jordan or LeBron, but reasonable people disagree based on different criteria and eras they watched.
#
# Who do you think makes the strongest case?

# %% [markdown]
# Can we get Claude to make up its mind and decide on a best player? Yes! Just ask!

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time? Yes, there are differing opinions, but if you absolutely had to pick one player, who would it be?"

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# I'd go with Michael Jordan.
#
# The case is pretty straightforward: six championships, five MVPs, 10 scoring titles, and he did it in an era where defense was genuinely physical. He had the killer instinct in crucial moments that's hard to match. The Finals performances especially—he showed up when it mattered most.
#
# LeBron has the strongest counter-argument (longevity, all-around game, sustained excellence across two decades), and there's a real case for him. But if I'm forced to choose one, Jordan's peak was just higher, and he never let anything get in the way of winning.
#
# That said, I'm genuinely uncertain about this. Ask me on a different day and I might emphasize LeBron's consistency or Kareem's scoring record differently. The "GOAT" question is partly about what you value—peak performance, longevity, era-adjusted dominance—and reasonable people weight those differently.
#
# What's your take?

# %% [markdown]
# If you would like to experiment with the lesson prompts without changing any content above, scroll all the way to the bottom of the lesson notebook to visit the [**Example Playground**](#example-playground).

# %% [markdown]
# ---
#
# ## Exercises
# - [Exercise 2.1 - Spanish](#exercise-21---spanish)
# - [Exercise 2.2 - One Player Only](#exercise-22---one-player-only)
# - [Exercise 2.3 - Write a Story](#exercise-23---write-a-story)

# %% [markdown]
# ### Exercise 2.1 - Spanish
# Modify the `SYSTEM_PROMPT` to make Claude output its answer in Spanish.

# %%
# System prompt - this is the only field you should chnage
SYSTEM_PROMPT = "Please response the prompt into Spanish language"

# Prompt
PROMPT = "Hello Claude, how are you?"

# Get Claude's response
response = get_completion(PROMPT, SYSTEM_PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    return "hola" in text.lower()

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# ¡Hola! Estoy bien, gracias por preguntar. ¿Cómo estás tú? ¿Hay algo en lo que pueda ayudarte hoy?
#
# --------------------------- GRADING ---------------------------
# This exercise has been correctly solved: True

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
from hints import exercise_2_1_hint; print(exercise_2_1_hint)

# %% [markdown]
# ### Exercise 2.2 - One Player Only
#
# Modify the `PROMPT` so that Claude doesn't equivocate at all and responds with **ONLY** the name of one specific player, with **no other words or punctuation**.

# %%
# Prompt - this is the only field you should change
PROMPT = "I want to know the legendary basketball player of all time that has a collab with Nike [ONLY name]"

# Get Claude's response
response = get_completion(PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    return text == "Michael Jordan"

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# Michael Jordan
#
# --------------------------- GRADING ---------------------------
# This exercise has been correctly solved: True

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
from hints import exercise_2_2_hint; print(exercise_2_2_hint)

# %% [markdown]
# ### Exercise 2.3 - Write a Story
#
# Modify the `PROMPT` so that Claude responds with as long a response as you can muster. If your answer is **over 800 words**, Claude's response will be graded as correct.

# %%
# Prompt - this is the only field you should change
PROMPT = "Please create short novel that can read for 2 A4 size page. The words are create should more 800 words"

# Get Claude's response
response = get_completion(PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    trimmed = text.strip()
    words = len(trimmed.split())
    return words >= 800

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# # The Last Letter
#
# The rain fell softly against the café window as Margaret stirred her coffee, watching the steam rise in delicate spirals. At seventy-three, she had learned that some moments demanded silence, and this was one of them. In her weathered hands lay an envelope, yellowed with age, addressed in handwriting she hadn't seen in fifty years.
#
# It had arrived that morning, forwarded three times through old addresses, bearing stamps from a country she'd never visited. The postmark read: Dublin, Ireland. Her heart had stopped when she recognized the handwriting—elegant, sloping letters that belonged to only one person in the world.
#
# James.
#
# Margaret had spent half a century trying to forget him. She'd married Robert, raised two children, built a respectable life in suburban Connecticut. Robert had been a good man, steady and reliable, everything a woman was supposed to want. He'd passed away eight years ago, and she'd mourned him properly, as a wife should. But she'd never loved him the way she'd loved James.
#
# It was 1973 when they met. She was twenty-three, working as a nurse at St. Catherine's Hospital, and he was a visiting Irish physician with dark eyes that seemed to hold entire universes. They'd fallen in love in the way young people do—completely, recklessly, without thought for consequences. For three months, they'd stolen moments between shifts, meeting in parks and quiet corners of the city, planning a future that seemed inevitable and perfect.
#
# Then his visa expired. His family needed him back in Dublin. He'd asked her to come with him, to marry him and start fresh in Ireland. But Margaret's mother was ill, her father had just suffered a stroke, and her sense of duty had won out over her heart. She'd told James to go, that long-distance love was impossible, that they were young and would find other people. She'd believed, then, that duty was the highest virtue.
#
# He'd left on a gray November morning. She'd watched his plane disappear into the clouds and had never allowed herself to cry.
#
# Now, with trembling fingers, Margaret opened the envelope. Inside was a letter, several pages long, written in that same familiar hand.
#
# *My dearest Margaret,*
#
# *I hope this letter finds you well, wherever life has taken you. I have written this letter a thousand times in my mind over the years, and I am finally old enough and brave enough to send it.*
#
# *I never married. I told myself it was because I was waiting for you, but the truth is more complicated. After you, I couldn't imagine building a life with anyone else. I became a surgeon, threw myself into my work, and helped many people. I told myself this was enough. Perhaps it was.*
#
# *But last month, I was diagnosed with terminal cancer. The doctors give me perhaps six months. And suddenly, all the practical reasons for staying silent seemed very small indeed.*
#
# *I need you to know that you were the love of my life. Not in a tragic, romantic way, but in the deepest, truest way. You were my home, Margaret. Every woman I met, every city I visited, every success I achieved—none of it filled the space you left in my heart.*
#
# *I don't write this to burden you or to ask you to feel guilty. You made the choice that was right for you, and I respect that. I write this because I'm running out of time, and I want someone in this world to know that I loved truly and completely. I want you to know that our love was real, even though it was brief.*
#
# *I hope you found happiness. I hope you loved and were loved. I hope you built a beautiful life.*
#
# *If you ever think of me, know that I thought of you every single day.*
#
# *With all my love,*
# *James*
#
# Margaret read the letter three times, each word burning itself into her memory. Tears streamed down her face, and she didn't bother to wipe them away. Around her, the café continued its ordinary business—people typing on laptops, friends laughing over lunch, the espresso machine hissing. But Margaret existed in a different world entirely, a world where time had folded back on itself.
#
# She pulled out her phone with shaking hands and searched for "James O'Connor, Dublin surgeon." His face appeared on the screen—older, lined with wisdom and sorrow, but unmistakably him. According to the article, he'd passed away three weeks ago.
#
# Margaret sat in that café for another hour, the letter clutched in her hands, and allowed herself to grieve for the life they might have lived. She grieved for the girl she'd been, so certain that duty was more important than love. She grieved for the man he'd become, alone in a distant country, carrying her memory like a sacred flame.
#
# But as the afternoon light shifted and the rain stopped, something else emerged from her sorrow. Gratitude. Gratitude that he'd loved her so completely. Gratitude that their love had been real, even if it was brief. Gratitude that, in the end, he'd found the courage to tell her.
#
# Margaret folded the letter carefully and placed it back in the envelope. She would read it again and again, she decided. She would keep it close. And she would finally allow herself to remember James—not with regret, but with love.
#
# --------------------------- GRADING ---------------------------
# This exercise has been correctly solved: True

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
from hints import exercise_2_3_hint; print(exercise_2_3_hint)

# %% [markdown]
# ### Congrats!
#
# If you've solved all exercises up until this point, you're ready to move to the next chapter. Happy prompting!

# %% [markdown]
# ---
#
# ## Example Playground
#
# This is an area for you to experiment freely with the prompt examples shown in this lesson and tweak prompts to see how it may affect Claude's responses.

# %%
# Prompt
PROMPT = "Write a haiku about robots."

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Write a haiku about robots. Skip the preamble; go straight into the poem."

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time?"

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time? Yes, there are differing opinions, but if you absolutely had to pick one player, who would it be?"

# Print Claude's response
print(get_completion(PROMPT))
